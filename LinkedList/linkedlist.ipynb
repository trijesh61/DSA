# %%
class Node:
    def __init__(self,value):
        self.data=value
        self.next=None

# %%
a=Node(1)

# %%
a

# %%
a.data
# Out:
# 1

# %%
print(a.next)
# Out:
# None

# %%
# Creating Empty LinkedList
class Node:
    def __init__(self,value):
        self.data=value
        self.next=None

class LinkedList:
    def __init__(self):
        self.head=None
        self.n=0
    def __len__(self):
        return self.n
